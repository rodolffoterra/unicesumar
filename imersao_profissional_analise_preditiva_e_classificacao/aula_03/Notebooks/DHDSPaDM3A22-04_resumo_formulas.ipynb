# %% [markdown]
# <img src='../../../common/DH_LOGO.jpeg' align='left' width=100%/>

# %%
# initial setup
#%run "../../../common/0_notebooks_base_setup.py"

# %% [markdown]
# # DHDSPaDM3A22 - Prática Guiada: Resumo de Fórmula

# %% [markdown]
# ## Resumo e fórmulas de regressão linear

# %% [markdown]
# ### Regressão Linear:
#
# $$
# H_{0}(X) =  \theta^{T}X  = \theta_{0}X_{0} + \theta_{1}X_{1} + \theta_{2}X_{2} + \theta_{3}X_{3} + \cdots +  \theta_{n}X_{n}
# $$
#
# Parâmetros =  $\theta_{0} , \theta_{1} ,  \theta_{2} + \cdots + \theta_{n}$.
#
# Função Custo = $J(\theta_{0},\theta_{1},\theta_{2} , \cdots,\theta_{n}) = \min_{u} f_{objetivo} = \frac{1}{2m} \sum_{i = 1}^{m}(y_{i}- \hat y_{i})^{2}$
#
#
# ### Solução matricial:
#
#
# $\theta = (X^{T}X)^{-1}X^{T} y$
#
#
# ### Algortimo descenso por gradiente.
#
# ![Train-Test Split](img/reg_lineal_desc_gradiente_1.png)
#
# ![Train-Test Split](img/reg_lineal_desc_gradient_2.png)
#
# em que $\alpha$ é a [taxa de aprendizagem](https://towardsdatascience.com/understanding-learning-rates-and-how-it-improves-performance-in-deep-learning-d0d4059c1c10), um hiperparâmetro que definimos a priori.
#
# ### Gradiente Descendente vs Solução matricial
#
# |             Gradiente Descendente           |           Solução matricial              |
# |:-------------------------------------------:|:----------------------------------------:|
# | É necessário definir $\alpha$               | Não é necessário definir $\alpha$        |
# | Necessita de muitas iterações               | Não necesita   iterações                 |
# | Ordem de complexidade quadrática O($n^{2}$) | Ordem de complexidade cúbica O($n^{3}$)  |
# | Admite colinearidade de variáveis           | Não admite colinearidade de variáveis    |

# %% [markdown]
# ## Referência
#
# - [Gradient Descent Explained](https://towardsdatascience.com/gradient-descent-explained-9b953fc0d2c)
